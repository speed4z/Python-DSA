# %% [markdown]
# ### Queue:
# Data Structure that stores data in First In First Out manner.
#
#     -Create queue
#     -enqueue
#     -dequeue
#     -peek
#     -delete
#     -isempty

# %% [markdown]
# ### Implementation
#     1.List
#         -queue without capacity
#         -queue with capacity (Circular queue)
#     2.Linked List

# %%
class queue:
    def __init__(self):
        self.items = []
        
    def __str__(self):
        values = [str(x) for x in self.items]
        return ' '.join(values)
    
    def isEmpty(self):
        if self.items == []:
            return True
        else:
            return False
    
    def enqueue(self,value):           #O(1)
        self.items.append(value)
        return "successfully inserted"
    
    def dequeue(self):                 #O(1)
        if self.isEmpty():
            return "List not found"
        else:
            return self.items.pop(0)

# %%
q = queue()
print(q.isEmpty())
# Out:
# True

# %%
q.enqueue(2)
q.enqueue(1)
q.enqueue(9)
q.enqueue(5)
q.enqueue(6)
print(q)
# Out:
# 2 1 9 5 6

# %%
print(q.dequeue())
print("after dequeue")
print(q)
# Out:
# 2
# after dequeue
# 1 9 5 6

# %%
def peek(self):            #O(1)
    if self.isEmpty():
        return "List not found"
    else:
        return self.items[0]

queue.peek = peek

# %%
print(q.peek())
print("after peek")
print(q)
# Out:
# 1
# after peek
# 1 9 5 6

# %% [markdown]
# ### Time and space complexities
# ![queue.png](attachment:queue.png)
