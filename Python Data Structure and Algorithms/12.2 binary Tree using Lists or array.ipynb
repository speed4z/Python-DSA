# %% [markdown]
# ### Binary tree Implementation using List
# ![bt%2002.png](attachment:bt%2002.png)

# %%
class BinaryTree:
    def __init__(self,size):
        self.customList = size *[None]
        self.lastUsedIndex = 0
        self.size = size

#create Binary Tree
newBT = BinaryTree(8)#8 is max size of tree
